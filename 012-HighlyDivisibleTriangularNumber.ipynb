# %% [markdown]
# ## Highly divisible triangular number

# %% [markdown]
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7th triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
#      1: 1
#      3: 1,3
#      6: 1,2,3,6
#     10: 1,2,5,10
#     15: 1,3,5,15
#     21: 1,3,7,21
#     28: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?
#
# https://www.dcode.fr/divisors-list-number

# %%
import pandas as pd

df = pd.read_csv('primes1.txt', delimiter= '\s+', index_col=False,header=None)

print(df.head(3))
# Out:
#     0   1   2   3   4   5   6   7
# 0   2   3   5   7  11  13  17  19
# 1  23  29  31  37  41  43  47  53
# 2  59  61  67  71  73  79  83  89

# %%
def isPrime(n):
    for i, row in df.iteritems(): 
        for j, col in row.iteritems():
            if col == n:
                return True
    return False

# %%
def get_divisors(n):
    res = [1]
    for i in range(2, int(n/2)+1):
        if(n%i == 0):
            res.append(i)
    return res

# %%
for i in range(1000,20000):
    triangN = 0
    for j in range(1,i+1):
        triangN += j
    if isPrime(triangN) == False:
        size = len(get_divisors(triangN))
        if size > 100:
            print(i, ": triangular number=", triangN, " size:", size)
        if(size == 500):
            print(i, ": triangular number=", triangN)
            print(get_divisors(triangN))
            break
# Out:
# 1088 : triangular number= 592416  size: 107
# 1104 : triangular number= 609960  size: 127
# 1175 : triangular number= 690900  size: 107
# 1215 : triangular number= 738720  size: 143
# 1224 : triangular number= 749700  size: 161
# 1280 : triangular number= 819840  size: 127
# 1287 : triangular number= 828828  size: 143
# 1295 : triangular number= 839160  size: 159
# 1364 : triangular number= 930930  size: 127
# 1407 : triangular number= 990528  size: 111
# 1440 : triangular number= 1037520  size: 119
# 1455 : triangular number= 1059240  size: 127

# %%
print(len(get_divisors(49995000)))
# Out:
# 239

# %%
t = 0
for j in range(1,20000):
    t += j
print(t)
# Out:
# 199990000

# %%
print(len(get_divisors(199990000)))
# Out:
# 99
